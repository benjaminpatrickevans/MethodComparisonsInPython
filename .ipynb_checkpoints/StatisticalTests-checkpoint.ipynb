# %%
import pandas as pd
import numpy as np
from scipy import stats
import scikit_posthocs as sp # https://pypi.org/project/scikit-posthocs/
import stac
import matplotlib.pyplot as plt

# %% [markdown]
# # Read in our data for comparing

# %%
# Assumes a formattting where rows are datasets, and the methods are columns
df = pd.read_csv("data/rankings.csv", index_col=0)
data = np.asarray(df)

print("Read data")

# To be safe, ensure this matches what was expected
num_datasets, num_methods = data.shape
print("Methods:", num_methods, "Datasets:", num_datasets)
# Out:
# Read data
# Methods: 12 Datasets: 10

# %% [markdown]
# ## Friedman testing
# Non parametric test to check if there is a difference in means between the groups (classifiers)

# %%
alpha = 0.05 # Set this to the desired alpha/signifance level

stat, p = stats.friedmanchisquare(*data)

reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True

# %% [markdown]
# ### Post Hoc Analysis
# See [Statistical Comparisons of Classifiers over Multiple Data Sets](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.141.3142&rep=rep1&type=pdf) for more detail

# %%
# At this point, we should only continue if H0 was rejected
if not reject:
    raise Exception("Exiting early. The rankings are only relevant if there was a difference in the means i.e. if we rejected h0 above")

# %%
# Helper functions for performing the statistical tests
def generate_scores(method, method_args, data, labels):
    pairwise_scores = method(data, **method_args) # Matrix for all pairwise comaprisons
    pairwise_scores.set_axis(labels, axis='columns', inplace=True) # Label the cols
    pairwise_scores.set_axis(labels, axis='rows', inplace=True) # Label the rows, note: same label as pairwise combinations
    return pairwise_scores

def plot(scores):
    # Pretty plot of significance
    heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'square': True,
                    'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}

    sp.sign_plot(scores, **heatmap_args)

# %% [markdown]
# #### Nemenyi Test
# Note: This is relevant when you would like to compare various methods.
# For example if you propose several methods and want to compare them all against each
# other, or to do an exhaustive comparison against several method. Often this is not
# what we want, as we propose only one method (instead see Bonferoni below), and this would
# be overconservativew.

# %%
nemenyi_scores = generate_scores(sp.posthoc_nemenyi_friedman, {}, data, df.columns)

# %%
# Shows the p values for each pair
nemenyi_scores
# Out:
#                           SVM  Logistic Regression      k-NN  Naive Bayes  \
# SVM                 -1.000000             0.900000  0.900000     0.900000
# Logistic Regression  0.900000            -1.000000  0.900000     0.900000
# k-NN                 0.900000             0.900000 -1.000000     0.900000
# Naive Bayes          0.900000             0.900000  0.900000    -1.000000
# Decision Tree        0.900000             0.900000  0.900000     0.900000
# Random Forest        0.900000             0.900000  0.900000     0.900000
# Adaboost             0.900000             0.900000  0.900000     0.900000
# Gradient Boosting    0.158407             0.900000  0.658378     0.560957
# Bagged NN            0.900000             0.900000  0.900000     0.900000
# Extra Trees          0.332588             0.900000  0.872707     0.775284
# Voting Classifier    0.075528             0.814256  0.482355     0.374579
# Proposed Method      0.001000             0.009587  0.001135     0.001000
#
#                      Decision Tree  Random Forest  Adaboost  \
# SVM                       0.900000        0.90000  0.900000
# Logistic Regression       0.900000        0.90000  0.900000
# k-NN                      0.900000        0.90000  0.900000
# Naive Bayes               0.900000        0.90000  0.900000
# Decision Tree            -1.000000        0.90000  0.900000
# Random Forest             0.900000       -1.00000  0.900000
# Adaboost                  0.900000        0.90000 -1.000000
# Gradient Boosting         0.135020        0.90000  0.900000
# Bagged NN                 0.900000        0.90000  0.900000
# Extra Trees               0.295047        0.90000  0.900000
# Voting Classifier         0.062844        0.90000  0.794768
# Proposed Method           0.001000        0.01685  0.008535
#
#                      Gradient Boosting  Bagged NN  Extra Trees  \
# SVM                           0.158407   0.900000     0.332588
# Logistic Regression           0.900000   0.900000     0.900000
# k-NN                          0.658378   0.900000     0.872707
# Naive Bayes                   0.560957   0.900000     0.775284
# Decision Tree                 0.135020   0.900000     0.295047
# Random Forest                 0.900000   0.900000     0.900000
# Adaboost                      0.900000   0.900000     0.900000
# Gradient Boosting            -1.000000   0.900000     0.900000
# Bagged NN                     0.900000  -1.000000     0.900000
# Extra Trees                   0.900000   0.900000    -1.000000
# Voting Classifier             0.900000   0.900000     0.900000
# Proposed Method               0.502507   0.018784     0.277058
#
#                      Voting Classifier  Proposed Method
# SVM                           0.075528         0.001000
# Logistic Regression           0.814256         0.009587
# k-NN                          0.482355         0.001135
# Naive Bayes                   0.374579         0.001000
# Decision Tree                 0.062844         0.001000
# Random Forest                 0.900000         0.016850
# Adaboost                      0.794768         0.008535
# Gradient Boosting             0.900000         0.502507
# Bagged NN                     0.900000         0.018784
# Extra Trees                   0.900000         0.277058
# Voting Classifier            -1.000000         0.677865
# Proposed Method               0.677865        -1.000000

# %%
plot(nemenyi_scores)

# %% [markdown]
# #### Bonferoni-Holm Correction
# In some cases, we do not care about all pairwise comparisons as we only propose a single method.
# In this case we can prefer using the Bonferroni correction with a a control method, where the
# control is our proposed method.  This is confirmed in Statistical Comparisons of Classifiers over Multiple Data Sets with
#
# "We thus should not make pairwise comparisons when we in fact only test whether a newly proposed method is better than the existing ones."
#
# This is done with the "Holm" method here
#
#
# **NOTE:** This relies on the method being called "*Proposed Method*" in the imported CSV file,
# for lack of a generic way to set the control group.

# %%
# This library requires the data in different format to above, so was tranposed
statistic, p_value, ranking, rank_cmp  = stac.friedman_test(*np.transpose(data))
ranks = {key: rank_cmp[i] for i, key in enumerate(list(df.columns))} 

comparisons, z_values, p_values, adj_p_values = stac.holm_test(ranks, control="Proposed Method")
adj_p_values = np.asarray(adj_p_values)

# %%
# Rankings
for method, rank in ranks.items():
    print(method +":", "%.2f" % rank)
# Out:
# SVM: 2.29
# Logistic Regression: 3.66
# k-NN: 3.13
# Naive Bayes: 2.98
# Decision Tree: 2.23
# Random Forest: 3.81
# Adaboost: 3.63
# Gradient Boosting: 5.15
# Bagged NN: 3.85
# Extra Trees: 4.81
# Voting Classifier: 5.43
# Proposed Method: 7.41

# %%
holm_scores = pd.DataFrame({"p": adj_p_values, "sig": adj_p_values < alpha}, index=comparisons)

# %%
holm_scores
# Out:
#                                                p   sig
# Proposed Method vs Decision Tree        0.000002  True
# Proposed Method vs SVM                  0.000003  True
# Proposed Method vs Naive Bayes          0.000083  True
# Proposed Method vs k-NN                 0.000150  True
# Proposed Method vs Adaboost             0.001084  True
# Proposed Method vs Logistic Regression  0.001084  True
# Proposed Method vs Random Forest        0.001609  True
# Proposed Method vs Bagged NN            0.001609  True
# Proposed Method vs Extra Trees          0.027584  True
# Proposed Method vs Gradient Boosting    0.047193  True
# Proposed Method vs Voting Classifier    0.047194  True
